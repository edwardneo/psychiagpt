# %%
from google.colab import drive
drive.mount('/content/drive/')
# %cd 'drive/MyDrive/PsychiaGPT/'
# Out:
# Mounted at /content/drive/
# /content/drive/.shortcut-targets-by-id/1jfN0s4xXvzbQXsQ6lIGh3Fq-Okr_0Xuf/PsychiaGPT
